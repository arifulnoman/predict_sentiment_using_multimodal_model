txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3511.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/597.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/4961.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3915.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3734.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/3066.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/4101.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/4374.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/4575.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/4185.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/248.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/4186.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2832.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/4605.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/4451.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3031.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/3200.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/4154.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/1377.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/4559.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/2480.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/631.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/999.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/461.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/1923.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/1021.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/136.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/1987.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/904.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/1015.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/4203.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2514.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/1728.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/1538.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/3706.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/1252.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/1861.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/4928.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/4391.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/1849.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/3811.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/1236.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/5051.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/3536.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2807.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/2151.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/3911.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/1976.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/1515.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/1141.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/3737.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/3496.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2018.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/4335.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/4143.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2861.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/3966.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3482.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/2999.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/2769.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2710.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/4729.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3774.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/3246.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3882.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2092.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2042.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/4680.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/1465.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3349.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/1743.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/5025.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/2884.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/3896.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3629.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/2747.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3695.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/925.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2969.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/3969.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/4466.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/1903.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/858.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/2689.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/583.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3613.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2114.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/4678.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2698.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/1449.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3495.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/454.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2607.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2966.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3997.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/605.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/754.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/1593.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/1554.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/753.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/364.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/3712.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/2691.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/90.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/4254.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/599.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/25.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2071.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/4490.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/3267.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/4374.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/754.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/1201.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/3120.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2867.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2508.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/783.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/1801.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/1351.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3240.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/4971.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/4421.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/854.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/1978.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/1979.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/4428.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3059.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2850.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/1867.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3228.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3529.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3410.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2085.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/1669.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/2359.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/4968.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2585.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/1507.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/147.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/5005.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/5047.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/4071.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/5088.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/3139.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3778.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/2109.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/921.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/823.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/4463.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/3950.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/728.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/94.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/1857.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/1656.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/1105.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/1034.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3953.txt
# /kaggle/input/mvsasingle/MVSA_Single/data/3361.jpg
# /kaggle/input/mvsasingle/MVSA_Single/data/2599.jpg

# %%
import os
import torch
import torchvision.transforms as transforms
from PIL import Image
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer, BertModel
from sklearn.model_selection import train_test_split
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torchvision.models as models

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Data loading functions
def load_text_data(data_folder):
    texts = []
    filenames = sorted(os.listdir(data_folder), key=lambda x: int(x[:-4]) if x[:-4].isdigit() else x)
    for filename in filenames:
        if filename.endswith(".txt"):
            with open(os.path.join(data_folder, filename), 'r', encoding='latin-1') as file:
                text = file.read().strip()
                texts.append(text)
    return texts, filenames

# %%
def load_labels(result_file):
    labels = {}
    with open(result_file, 'r') as file:
        next(file)  # Skip header
        for line in file:
            parts = line.strip().split('\t')
            text_id = int(parts[0])
            text_label, image_label = parts[1].split(',')
            labels[text_id] = text_label.strip()
    return labels

# %%
def filter_existing_files(texts, filenames, labels, data_folder):
    existing_texts = []
    existing_images = []
    existing_labels = []
    for i, text in enumerate(texts):
        image_file = os.path.join(data_folder, f"{i+1}.jpg")
        if os.path.exists(image_file) and (i+1) in labels:
            existing_texts.append(text)
            existing_images.append(image_file)
            existing_labels.append(labels[i+1])
    return existing_texts, existing_images, existing_labels

# %%
# Paths
data_folder = "/kaggle/input/mvsasingle/MVSA_Single/data/"
result_file = '/kaggle/input/mvsasingle/MVSA_Single/labelResultAll.txt'

# Load data
texts, filenames = load_text_data(data_folder)
labels = load_labels(result_file)

# Filter existing files
texts, image_paths, labels = filter_existing_files(texts, filenames, labels, data_folder)

# %%
class MultimodalDataset(Dataset):
    def __init__(self, texts, images, labels, tokenizer, transform):
        self.texts = texts
        self.images = images
        self.labels = labels
        self.tokenizer = tokenizer
        self.transform = transform

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        image_path = self.images[idx]
        try:
            image = Image.open(image_path).convert('RGB')
        except FileNotFoundError:
            print(f"File not found: {image_path}")
            image = Image.new('RGB', (224, 224))  # Create a blank image

        label = self.labels[idx]

        encoded_text = self.tokenizer(text, padding='max_length', truncation=True, max_length=128, return_tensors='pt')
        image = self.transform(image)

        return {
            'text': encoded_text['input_ids'].squeeze(),
            'attention_mask': encoded_text['attention_mask'].squeeze(),
            'image': image,
            'label': torch.tensor(self.sentiment_to_label[label], dtype=torch.long)
        }

    sentiment_to_label = {'negative': 0, 'neutral': 1, 'positive': 2}

# %%
# Prepare tokenizer and transforms
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
val_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
# Split the data
train_texts, val_texts, train_images, val_images, train_labels, val_labels = train_test_split(
    texts, image_paths, labels, test_size=0.2, random_state=42, stratify=labels
)

# %%
# Create datasets and dataloaders
train_dataset = MultimodalDataset(train_texts, train_images, train_labels, tokenizer, train_transform)
val_dataset = MultimodalDataset(val_texts, val_images, val_labels, tokenizer, val_transform)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# %%
class MultimodalSentimentModel(nn.Module):
    def __init__(self, bert_model, resnet_model, num_classes):
        super(MultimodalSentimentModel, self).__init__()
        self.text_model = bert_model
        self.image_model = resnet_model
        
        self.text_output_size = 768  # BERT output size
        self.image_output_size = 2048  # ResNet50 output size
        
        self.attention = nn.MultiheadAttention(self.text_output_size + self.image_output_size, 8)
        self.fc1 = nn.Linear(self.text_output_size + self.image_output_size, 512)
        self.fc2 = nn.Linear(512, num_classes)
        self.dropout = nn.Dropout(0.5)

    def forward(self, input_ids, attention_mask, image):
        text_output = self.text_model(input_ids=input_ids, attention_mask=attention_mask)[1]
        image_output = self.image_model(image)
        
        combined = torch.cat((text_output, image_output), dim=1)
        combined = combined.unsqueeze(0)
        attn_output, _ = self.attention(combined, combined, combined)
        attn_output = attn_output.squeeze(0)
        
        x = self.fc1(attn_output)
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
# Initialize models
bert_model = BertModel.from_pretrained('bert-base-uncased')
resnet_model = models.resnet50(pretrained=True)
resnet_model.fc = nn.Identity()  # Remove the final fully connected layer
model = MultimodalSentimentModel(bert_model, resnet_model, num_classes=3).to(device)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 147MB/s]

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=2e-5)
scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=3, factor=0.1)

# %%
# Training loop
num_epochs = 50
best_val_loss = float('inf')
patience = 5
patience_counter = 0

for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    train_correct = 0
    train_total = 0

    for batch in train_loader:
        input_ids = batch['text'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        images = batch['image'].to(device)
        labels = batch['label'].to(device)

        optimizer.zero_grad()
        outputs = model(input_ids, attention_mask, images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = outputs.max(1)
        train_total += labels.size(0)
        train_correct += predicted.eq(labels).sum().item()

    train_loss /= len(train_loader)
    train_acc = train_correct / train_total

    # Validation
    model.eval()
    val_loss = 0
    val_correct = 0
    val_total = 0

    with torch.no_grad():
        for batch in val_loader:
            input_ids = batch['text'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            images = batch['image'].to(device)
            labels = batch['label'].to(device)

            outputs = model(input_ids, attention_mask, images)
            loss = criterion(outputs, labels)

            val_loss += loss.item()
            _, predicted = outputs.max(1)
            val_total += labels.size(0)
            val_correct += predicted.eq(labels).sum().item()

    val_loss /= len(val_loader)
    val_acc = val_correct / val_total

    print(f'Epoch {epoch+1}/{num_epochs}:')
    print(f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}')
    print(f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')

    scheduler.step(val_loss)

    if val_loss < best_val_loss:
        best_val_loss
# Out:
# Epoch 1/50:
# Train Loss: 1.0715, Train Acc: 0.4098
# Val Loss: 1.1138, Val Acc: 0.4132
# Epoch 2/50:
# Train Loss: 0.9717, Train Acc: 0.5197
# Val Loss: 0.9387, Val Acc: 0.5575
# Epoch 3/50:
# Train Loss: 0.7936, Train Acc: 0.6444
# Val Loss: 1.1436, Val Acc: 0.5108
# Epoch 4/50:
# Train Loss: 0.6193, Train Acc: 0.7486
# Val Loss: 1.1461, Val Acc: 0.5347
# Epoch 5/50:
# Train Loss: 0.3993, Train Acc: 0.8421
# Val Loss: 1.4310, Val Acc: 0.5542
# Epoch 6/50:
# Train Loss: 0.2815, Train Acc: 0.8991
# Val Loss: 1.4902, Val Acc: 0.5477
# Epoch 7/50:
# Train Loss: 0.1298, Train Acc: 0.9623
# Val Loss: 1.6259, Val Acc: 0.5575
# Epoch 8/50:
# Train Loss: 0.1195, Train Acc: 0.9623
# Val Loss: 1.7532, Val Acc: 0.5607
# Epoch 9/50:
# Train Loss: 0.0894, Train Acc: 0.9704
# Val Loss: 1.8764, Val Acc: 0.5640
# Epoch 10/50:
# Train Loss: 0.0822, Train Acc: 0.9740
# Val Loss: 1.9534, Val Acc: 0.5640
# Epoch 11/50:
# Train Loss: 0.0744, Train Acc: 0.9772
# Val Loss: 1.9595, Val Acc: 0.5607
# Epoch 12/50:
# Train Loss: 0.0744, Train Acc: 0.9750
# Val Loss: 1.9567, Val Acc: 0.5705
# Epoch 13/50:
# Train Loss: 0.0732, Train Acc: 0.9742
# Val Loss: 1.9801, Val Acc: 0.5662
# Epoch 14/50:
# Train Loss: 0.0625, Train Acc: 0.9794
# Val Loss: 1.9918, Val Acc: 0.5651
# Epoch 15/50:
# Train Loss: 0.0710, Train Acc: 0.9737
# Val Loss: 1.9854, Val Acc: 0.5694
# Epoch 16/50:
# Train Loss: 0.0724, Train Acc: 0.9780
# Val Loss: 1.9892, Val Acc: 0.5683
# Epoch 17/50:
# Train Loss: 0.0706, Train Acc: 0.9745
# Val Loss: 1.9913, Val Acc: 0.5651
# Epoch 18/50:
# Train Loss: 0.0695, Train Acc: 0.9772
# Val Loss: 1.9848, Val Acc: 0.5672
# Epoch 19/50:
# Train Loss: 0.0712, Train Acc: 0.9772
# Val Loss: 1.9932, Val Acc: 0.5629
# Epoch 20/50:
# Train Loss: 0.0708, Train Acc: 0.9775
# Val Loss: 1.9920, Val Acc: 0.5629
# Epoch 21/50:
# Train Loss: 0.0726, Train Acc: 0.9797
# Val Loss: 1.9899, Val Acc: 0.5640
# Epoch 22/50:
# Train Loss: 0.0723, Train Acc: 0.9750
# Val Loss: 1.9876, Val Acc: 0.5694
# Epoch 23/50:
# Train Loss: 0.0691, Train Acc: 0.9750
# Val Loss: 1.9845, Val Acc: 0.5618
# Epoch 24/50:
# Train Loss: 0.0666, Train Acc: 0.9783
# Val Loss: 1.9982, Val Acc: 0.5694
# Epoch 25/50:
# Train Loss: 0.0716, Train Acc: 0.9756
# Val Loss: 1.9895, Val Acc: 0.5629
# Epoch 26/50:
# Train Loss: 0.0700, Train Acc: 0.9788
# Val Loss: 1.9908, Val Acc: 0.5629
# Epoch 27/50:
# Train Loss: 0.0683, Train Acc: 0.9799
# Val Loss: 1.9919, Val Acc: 0.5705
# Epoch 28/50:
# Train Loss: 0.0680, Train Acc: 0.9788
# Val Loss: 1.9887, Val Acc: 0.5672
# Epoch 29/50:
# Train Loss: 0.0677, Train Acc: 0.9772
# Val Loss: 1.9914, Val Acc: 0.5662
# Epoch 30/50:
# Train Loss: 0.0667, Train Acc: 0.9756
# Val Loss: 1.9986, Val Acc: 0.5662
# Epoch 31/50:
# Train Loss: 0.0691, Train Acc: 0.9783
# Val Loss: 1.9920, Val Acc: 0.5694
# Epoch 32/50:
# Train Loss: 0.0685, Train Acc: 0.9778
# Val Loss: 1.9878, Val Acc: 0.5683
# Epoch 33/50:
# Train Loss: 0.0666, Train Acc: 0.9799
# Val Loss: 1.9998, Val Acc: 0.5651
# Epoch 34/50:
# Train Loss: 0.0704, Train Acc: 0.9759
# Val Loss: 1.9914, Val Acc: 0.5651
# Epoch 35/50:
# Train Loss: 0.0771, Train Acc: 0.9750
# Val Loss: 1.9936, Val Acc: 0.5640
# Epoch 36/50:
# Train Loss: 0.0694, Train Acc: 0.9802
# Val Loss: 1.9934, Val Acc: 0.5640
# Epoch 37/50:
# Train Loss: 0.0678, Train Acc: 0.9788
# Val Loss: 1.9863, Val Acc: 0.5618
# Epoch 38/50:
# Train Loss: 0.0662, Train Acc: 0.9767
# Val Loss: 1.9932, Val Acc: 0.5651
# Epoch 39/50:
# Train Loss: 0.0705, Train Acc: 0.9783
# Val Loss: 1.9963, Val Acc: 0.5694
# Epoch 40/50:
# Train Loss: 0.0743, Train Acc: 0.9737
# Val Loss: 1.9935, Val Acc: 0.5651
# Epoch 41/50:
# Train Loss: 0.0671, Train Acc: 0.9799
# Val Loss: 1.9928, Val Acc: 0.5651
# Epoch 42/50:
# Train Loss: 0.0702, Train Acc: 0.9780
# Val Loss: 2.0008, Val Acc: 0.5651
# Epoch 43/50:
# Train Loss: 0.0700, Train Acc: 0.9753
# Val Loss: 1.9990, Val Acc: 0.5640
# Epoch 44/50:
# Train Loss: 0.0697, Train Acc: 0.9780
# Val Loss: 1.9975, Val Acc: 0.5662
# Epoch 45/50:
# Train Loss: 0.0695, Train Acc: 0.9761
# Val Loss: 1.9925, Val Acc: 0.5651
# Epoch 46/50:
# Train Loss: 0.0649, Train Acc: 0.9783
# Val Loss: 2.0024, Val Acc: 0.5694
# Epoch 47/50:
# Train Loss: 0.0707, Train Acc: 0.9767
# Val Loss: 2.0019, Val Acc: 0.5694
# Epoch 48/50:
# Train Loss: 0.0712, Train Acc: 0.9750
# Val Loss: 1.9977, Val Acc: 0.5651
# Epoch 49/50:
# Train Loss: 0.0740, Train Acc: 0.9753
# Val Loss: 2.0001, Val Acc: 0.5651
# Epoch 50/50:
# Train Loss: 0.0684, Train Acc: 0.9786
# Val Loss: 1.9912, Val Acc: 0.5672

# %%
def predict_sentiment(model, image_path, caption):
    model.eval()
    
    # Preprocess image
    image = Image.open(image_path).convert('RGB')
    transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
    image = transform(image).unsqueeze(0).to(device)

    # Preprocess text
    encoded_text = tokenizer(caption, padding='max_length', truncation=True, max_length=128, return_tensors='pt')
    input_ids = encoded_text['input_ids'].to(device)
    attention_mask = encoded_text['attention_mask'].to(device)

    with torch.no_grad():
        outputs = model(input_ids, attention_mask, image)
        probabilities = torch.softmax(outputs, dim=1)
        sentiment_scores = probabilities.tolist()[0]
        predicted = torch.argmax(outputs, dim=1)

    sentiment_labels = ['negative', 'neutral', 'positive']
    sentiment = sentiment_labels[predicted.item()]
    return sentiment, sentiment_scores

# Example usage
image_path = '/kaggle/input/mvsasingle/MVSA_Single/data/80.jpg'
caption = 'Grab your brain mittens twitter I\'m super ecstatic to be at work.. ??'
sentiment, scores = predict_sentiment(model, image_path, caption)
print(f"Predicted sentiment: {sentiment}")
print(f"Sentiment scores: Negative: {scores[0]:.4f}, Neutral: {scores[1]:.4f}, Positive: {scores[2]:.4f}")
# Out:
# Predicted sentiment: negative
# Sentiment scores: Negative: 0.9877, Neutral: 0.0000, Positive: 0.0122

# %%
for i in range(1, 26):  # Iterate from 1 to 25
    image_path = f'/kaggle/input/mvsasingle/MVSA_Single/data/{i}.jpg'
    caption = texts[i - 1]  # texts list is 0-indexed, i starts from 1
    actual_label = labels[i]  # Assuming labels dictionary is 1-indexed

    sentiment, scores = predict_sentiment(model, image_path, caption)

    # Convert scores to percentages
    total_score = sum(scores)
    scores_percentage = [score / total_score * 100 for score in scores]

    # Print results
    print(f"Index: {i}")
    print(f"Actual Label (Image): {actual_label}")
    print(f"Actual Caption: {caption}")
    print(f"Predicted Sentiment: {sentiment}")
    print(f"Sentiment Scores: Negative: {scores_percentage[0]:.2f}%, Neutral: {scores_percentage[1]:.2f}%, Positive: {scores_percentage[2]:.2f}%")
    print("-" * 50)
# Out:
# Index: 1
# Actual Label (Image): 0
# Actual Caption: How I feel today #legday #jelly #aching #gym
# Predicted Sentiment: neutral
# Sentiment Scores: Negative: 0.01%, Neutral: 99.98%, Positive: 0.00%
# --------------------------------------------------
# Index: 2
# Actual Label (Image): 1
# Actual Caption: grattis min griskulting!!!???? va bara tvungen oki s? sch ? @ingenkommeratttrodig #pig #happybday #wow #lovely #cut¡­
# Predicted Sentiment: neutral
# Sentiment Scores: Negative: 0.05%, Neutral: 99.93%, Positive: 0.02%
# --------------------------------------------------
# Index: 3
# Actual Label (Image): 2
# Actual Caption: RT @polynminion: The moment I found my favourite tV character. #PROFOUNDLOVE
# Predicted Sentiment: neutral
# Sentiment Scores: Negative: 0.72%, Neutral: 99.27%, Positive: 0.01%
# --------------------------------------------------
# Index: 4
# Actual Label (Image): 0
# Actual Caption: #escort We have a young and energetic team and we pride ourselves on offering the highes #hoer
# Predicted Sentiment: positive
# Sentiment Scores: Negative: 0.01%, Neutral: 0.37%, Positive: 99.62%
# --------------------------------------------------
# Index: 5
# Actual Label (Image): 1
# Actual Caption: RT @chrisashaffer: Went to SSC today to be a "movie star" to rep for the Deaf and got to meet an energetic great guy: Mark White!
# Predicted Sentiment: positive
# Sentiment Scores: Negative: 0.00%, Neutral: 0.00%, Positive: 100.00%
# --------------------------------------------------
# Index: 6
# Actual Label (Image): 2
# Actual Caption: RT @babeshawnmendes: "that was really energetic"
# Predicted Sentiment: positive
# Sentiment Scores: Negative: 0.09%, Neutral: 0.00%, Positive: 99.91%
# --------------------------------------------------
# Index: 7
# Actual Label (Image): 2
# Actual Caption: RT @deepikapadukone: To my most hard working,fun loving and energetic team...Thank you and I love you!
# Predicted Sentiment: positive
# Sentiment Scores: Negative: 0.77%, Neutral: 0.01%, Positive: 99.22%
# --------------------------------------------------
# Index: 8
# Actual Label (Image): 2
# Actual Caption: Energetic training today with our San Antonio New Dollars/New Partners trainees
# Predicted Sentiment: positive
# Sentiment Scores: Negative: 0.03%, Neutral: 0.01%, Positive: 99.96%
# --------------------------------------------------
# Index: 9
# Actual Label (Image): 2
# Actual Caption: Look at their Photo and feel the #Anger. #SpeakUp for #peace. Speak up for #equality. Speak up for #Tolerance.
# Predicted Sentiment: positive
# Sentiment Scores: Negative: 0.07%, Neutral: 0.12%, Positive: 99.81%
# --------------------------------------------------
# Index: 10
# Actual Label (Image): 1
# Actual Caption: @ArrivaTW absolute disgrace two carriages from Bangor half way there standing room only #disgraced
# Predicted Sentiment: negative
# Sentiment Scores: Negative: 64.22%, Neutral: 35.69%, Positive: 0.09%
# --------------------------------------------------
# Index: 11
# Actual Label (Image): 1
# Actual Caption: RT @Dthompsonsmile: So proud of these kids! Not only talented, ENERGETIC and hardworking, but respectful and kind-hearted! ??
# Predicted Sentiment: positive
# Sentiment Scores: Negative: 0.04%, Neutral: 0.00%, Positive: 99.96%
# --------------------------------------------------
# Index: 12
# Actual Label (Image): 1
# Actual Caption: RT @cosy_cosy: What does everybody think of these candles from Liberty London. We love! RT if you feel the same #Valentinesday
# Predicted Sentiment: positive
# Sentiment Scores: Negative: 0.00%, Neutral: 0.07%, Positive: 99.93%
# --------------------------------------------------
# Index: 13
# Actual Label (Image): 1
# Actual Caption: I can't even tell you guys how much I love these covers ? @Melissa_Landers #invaded #alienated #prettycovers
# Predicted Sentiment: positive
# Sentiment Scores: Negative: 0.00%, Neutral: 0.01%, Positive: 99.99%
# --------------------------------------------------
# Index: 14
# Actual Label (Image): 0
# Actual Caption: RT @ChesterPerforms: An energetic @sbutlerbooks tells us all about his sister - "the most evil bumface in the world'!! #WayWord #Chester ht¡­
# Predicted Sentiment: positive
# Sentiment Scores: Negative: 0.05%, Neutral: 0.02%, Positive: 99.94%
# --------------------------------------------------
# Index: 15
# Actual Label (Image): 1
# Actual Caption: Awesome record. Keepin the night energetic ??
# Predicted Sentiment: positive
# Sentiment Scores: Negative: 0.00%, Neutral: 0.10%, Positive: 99.90%
# --------------------------------------------------
# Index: 16
# Actual Label (Image): 2
# Actual Caption: RT @VenusCaelestis: You are a #manifestation of energetic potential. #truth #quote #DivineSociety
# Predicted Sentiment: positive
# Sentiment Scores: Negative: 0.01%, Neutral: 0.01%, Positive: 99.98%
# --------------------------------------------------
# Index: 17
# Actual Label (Image): 2
# Actual Caption: Love to party? We're hiring fun, outgoing, energetic & happy people. Call or visit us to learn more.
# Predicted Sentiment: positive
# Sentiment Scores: Negative: 0.03%, Neutral: 0.05%, Positive: 99.92%
# --------------------------------------------------
# Index: 18
# Actual Label (Image): 2
# Actual Caption: RT @JoeyXcv: when a girl texts you first and then ignores your reply
# Predicted Sentiment: neutral
# Sentiment Scores: Negative: 0.00%, Neutral: 99.99%, Positive: 0.01%
# --------------------------------------------------
# Index: 19
# Actual Label (Image): 1
# Actual Caption: #depressed #depression #bullied #anxiety #overdosed #addict #drugs #pills #cuts #cutting #¡­
# Predicted Sentiment: negative
# Sentiment Scores: Negative: 99.87%, Neutral: 0.07%, Positive: 0.06%
# --------------------------------------------------
# Index: 20
# Actual Label (Image): 1
# Actual Caption: Winners will be chosen in 1 week.
# Predicted Sentiment: neutral
# Sentiment Scores: Negative: 0.00%, Neutral: 100.00%, Positive: 0.00%
# --------------------------------------------------
# Index: 21
# Actual Label (Image): 2
# Actual Caption: Thank you to Eastwood 8th grader Sam L. for helping hang 7th grade #SafeDates Valentines Day cards. #Caring
# Predicted Sentiment: positive
# Sentiment Scores: Negative: 0.00%, Neutral: 0.01%, Positive: 99.99%
# --------------------------------------------------
# Index: 22
# Actual Label (Image): 1
# Actual Caption: Enraged by this? Then spread awareness! Loyalty...betrayed... #StopYulin2015
# Predicted Sentiment: negative
# Sentiment Scores: Negative: 99.99%, Neutral: 0.01%, Positive: 0.00%
# --------------------------------------------------
# Index: 23
# Actual Label (Image): 1
# Actual Caption: I am enthusiastic about Gleeeeeeeeeeeeeeeeeeee????
# Predicted Sentiment: positive
# Sentiment Scores: Negative: 0.01%, Neutral: 0.00%, Positive: 99.99%
# --------------------------------------------------
# Index: 24
# Actual Label (Image): 1
# Actual Caption: Looking forward to #Disgraced by Ayad Akhtar! Monday and tuesday are already sold out!
# Predicted Sentiment: positive
# Sentiment Scores: Negative: 0.62%, Neutral: 0.32%, Positive: 99.05%
# --------------------------------------------------
# Index: 25
# Actual Label (Image): 2
# Actual Caption: RT @curiosityhouse: Author @CarolynjMorris reads to an enthusiastic audience #BigHeartDays @CreemoreOntario
# Predicted Sentiment: neutral
# Sentiment Scores: Negative: 0.08%, Neutral: 99.83%, Positive: 0.10%
# --------------------------------------------------
